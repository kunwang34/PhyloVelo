# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import venn

# %%
from matplotlib.pylab import mpl

# %%
datas = pd.DataFrame(columns=['datasets', 'log_p', 'is_shuffle'])

# %%
data1 = pd.read_csv('./megs/standard_analysis/embryo2.csv', index_col=0)
data2 = pd.read_csv('./megs/standard_analysis/embryo3.csv', index_col=0)
data3 = pd.read_csv('./megs/standard_analysis/embryo1.csv', index_col=0)
data4 = pd.read_csv('./megs/standard_analysis/embryo6.csv', index_col=0)
data_p = np.log10(np.concatenate((data1['q_value'], data2['q_value'],data3['q_value'], data4['q_value'])))

data1s = pd.read_csv('./megs/permutation_analysis/embryo2_permutation.csv', index_col=0)
data2s = pd.read_csv('./megs/permutation_analysis/embryo3_permutation.csv', index_col=0)
data3s = pd.read_csv('./megs/permutation_analysis/embryo1_permutation.csv', index_col=0)
data4s = pd.read_csv('./megs/permutation_analysis/embryo6_permutation.csv', index_col=0)
data_ps = np.log10(np.concatenate((data1s['q_value'], data2s['q_value'],data3s['q_value'], data4s['q_value'])))

embryo_megs = np.concatenate((data1.index, data2.index, data3.index, data4.index))
# Out:
# /tmp/ipykernel_13147/168369328.py:5: RuntimeWarning: divide by zero encountered in log10
#   data_p = np.log10(np.concatenate((data1['q_value'], data2['q_value'],data3['q_value'], data4['q_value'])))

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['Embryo E8/E8.5']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/2585355696.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/kp3435.csv', index_col=0)
data2 = pd.read_csv('./megs/standard_analysis/kp3726.csv', index_col=0)
data_p = np.log10(np.concatenate((data1['q_value'], data2['q_value'])))

data1s = pd.read_csv('./megs/permutation_analysis/kp3435_permutation.csv', index_col=0)
data2s = pd.read_csv('./megs/permutation_analysis/kp3726_permutation.csv', index_col=0)
data_ps = np.log10(np.concatenate((data1s['q_value'], data2s['q_value'])))

kp_megs = np.concatenate((data1.index, data2.index))

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['KP lung tumor']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/2154367359.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/KPCY.csv', index_col=0)
data_p = np.log10((data1['q_value']))

data1s = pd.read_csv('./megs/permutation_analysis/KPCY_permutation.csv', index_col=0)
data_ps = np.log10((data1s['q_value']))

kpcy_megs = np.array(data1.index)

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['KPCY']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/666097374.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/a549-lg1.csv', index_col=0)
data2 = pd.read_csv('./megs/standard_analysis/a549-lg2.csv', index_col=0)
data_p = np.log10(np.concatenate((data1['q_value'], data2['q_value'])))

data1s = pd.read_csv('./megs/permutation_analysis/a549-lg1_permutation.csv', index_col=0)
data2s = pd.read_csv('./megs/permutation_analysis/a549-lg2_permutation.csv', index_col=0)
data_ps = np.log10(np.concatenate((data1s['q_value'], data2s['q_value'])))

a549_megs = np.concatenate((data1.index, data2.index))

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['A549']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/1307281641.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/HEK293T.csv', index_col=0)
data_p = np.log10((data1['q_value']))

data1s = pd.read_csv('./megs/permutation_analysis/HEK293T_permutation.csv', index_col=0)
data_ps = np.log10((data1s['q_value']))

hek_megs = np.array(data1.index)

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['HEK293T']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/2138768528.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/mouse_hematopoiesis.csv', index_col=0)
data_p = np.log10((data1['q_value']))

data1s = pd.read_csv('./megs/permutation_analysis/mouse_hematopoiesis_permutation.csv', index_col=0)
data_ps = np.log10((data1s['q_value']))

larry_megs = np.array(data1.index)

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['In vitro hematopoiesis']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/4253316465.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
data1 = pd.read_csv('./megs/standard_analysis/tcells.csv', index_col=0)
data_p = np.log10((data1['q_value']))

data1s = pd.read_csv('./megs/permutation_analysis/tcells_permutation.csv', index_col=0)
data_ps = np.log10((data1s['q_value']))

tcell_megs = np.array(data1.index)

# %%
logp = np.concatenate((data_p, data_ps))
iss = np.concatenate(([False]*len(data_p), [True]*len(data_ps)))
dataset = np.array(['CD8+ T cells']*len(logp))
data = np.vstack((dataset, logp, iss)).T
data = pd.DataFrame(data=data, columns=['datasets', 'log_p', 'is_shuffle'])

datas = datas.append(data)
# Out:
# /tmp/ipykernel_13147/3125182370.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datas = datas.append(data)

# %%
datas['log_p'] = datas['log_p'].astype(float)

# %%
datas['log_p'] = np.clip(datas['log_p'], a_min=-10, a_max=2)

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')

# %%
def convert(x):
    if x == 'False':
        return 'Standard analysis'
    else:
        return 'Permutation analysis'

# %%
datas['new'] = datas['is_shuffle'].apply(convert)

# %%
set(datas['datasets'])
# Out:
# {'A549',
#  'CD8+ T cells',
#  'Embryo E8/E8.5',
#  'HEK293T',
#  'In vitro hematopoiesis',
#  'KP lung tumor',
#  'KPCY'}

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.violinplot(data=datas, x='datasets', y='log_p', hue='new', palette="Pastel1", )

# ax.tick_params(axis='x', labelrotation=20)
ax.legend(loc=0)
ax.set_ylabel('log$_{10}$(q value)')
ax.set_xlabel('')
plt.xticks(rotation=30)
x0,x1 = ax.get_xlim()
ax.hlines(np.log10(0.05), x0, x1, linestyles='dashed', colors='black')
ax.set_xlim(x0, x1)
# Out:
# (-0.5, 6.5)

# %%
import phylovelo as pv
# Out:
# /home/wangkun/miniconda3/lib/python3.9/site-packages/phylovelo/sim_utils.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
kp3435 = pd.read_csv('./megs/kp3435.csv', index_col=0)
kp3726 = pd.read_csv('./megs/kp_3726.csv', index_col=0)

# %%
kpcy[kpcy['velocity']>0]
# Out:
#         velocity       p_value   q_value
# Gene
# Eloc    0.055484  3.015804e-03  0.004582
# Bend6   0.047128  1.065347e-03  0.002464
# Fhl2    0.074416  1.370668e-03  0.002830
# Ndufs1  0.035754  2.733646e-03  0.004354
# Epha4   0.025923  8.746104e-08  0.000005
# ...          ...           ...       ...
# Xist    0.013272  1.245546e-04  0.000696
# Kdm6a   0.035406  1.653108e-03  0.003159
# Emd     0.005920  1.186181e-03  0.002569
# Rpl36a  0.029264  4.435982e-04  0.001562
# Eif1ax  0.062311  2.843669e-04  0.001157
#
# [278 rows x 3 columns]

# %%
commgenes = list(set(kp3435.index).intersection(set(kp3726.index)))

# %%
plt.rcParams['font.size']=12

# %%
fig, ax = plt.subplots(figsize=(6, 6))
pv.corr_plot(kp3435.loc[commgenes]['velocity'], kp3726.loc[commgenes]['velocity'], ax, fontsize=12)
ax.set_xlabel('Velocity 3435_NT_T1')
ax.set_ylabel('Velocity 3726_NT_T1')
# Out:
# Text(0, 0.5, 'Velocity 3726_NT_T1')

# %%
vels_em1 = pd.read_csv('./megs/embryo1_all_mutnum.csv', index_col=0)
vels_em2 = pd.read_csv('./megs/embryo2_all_mutnum.csv', index_col=0)
vels_em3 = pd.read_csv('./megs/embryo3_all_mutnum.csv', index_col=0)
vels_em6 = pd.read_csv('./megs/embryo6_all_mutnum.csv', index_col=0)

# %%
vels_em6.shape
# Out:
# (425, 3)

# %%
import matplotlib

# %%
vels_em1 = pd.read_csv('./megs/embryo1_all_mutnum.csv', index_col=0)
vels_em2 = pd.read_csv('./megs/embryo2_all_mutnum.csv', index_col=0)
vels_em3 = pd.read_csv('./megs/embryo3_all_mutnum.csv', index_col=0)
vels_em6 = pd.read_csv('./megs/embryo6_all_mutnum.csv', index_col=0)
a549_lg1 = pd.read_csv('./megs/a549-lg1.csv', index_col=0)
a549_lg2 = pd.read_csv('./megs/a549-lg2.csv', index_col=0)
kpcy = pd.read_csv('./megs/KPCY.csv', index_col=0)
hek = pd.read_csv('./megs/HEK293T.csv', index_col=0)

# %%
embryo_genes = set(sum([list(vels_em1.index),list(vels_em2.index),list(vels_em3.index),list(vels_em6.index)], []))
a549_genes = set(list(a549_lg1.index) + list(a549_lg2.index))
kpcy_genes = set(list(kpcy.index))
hek_genes = set(list(hek.index))

# %%
# kp_genes = set(list(pd.read_csv('/home/wangkun/datas/gene_list/KP3435.csv', index_col=0).to_numpy().flatten())).union(set(list(pd.read_csv('/home/wangkun/datas/gene_list/KP3726.csv', index_col=0).to_numpy().flatten())))
# a549_genes = set(list(pd.read_csv('/home/wangkun/datas/gene_list/lg1.csv', index_col=0).to_numpy().flatten())).union(set(list(pd.read_csv('/home/wangkun/datas/gene_list/lg2.csv', index_col=0).to_numpy().flatten())))
# hek_genes = set(list(pd.read_csv('/home/wangkun/datas/gene_list/HEK293T.csv', index_col=0).to_numpy().flatten()))
# kpcy_genes = set(list(pd.read_csv('/home/wangkun/datas/gene_list/KPCY.csv', index_col=0).to_numpy().flatten()))

# %%
labels = venn.get_labels([a549_genes, hek_genes])
venn.venn2(labels, names=['A549 cell line', 'HEK293T cell line'], fontsize=20)
# Out:
# /home/wangkun/miniconda3/lib/python3.9/site-packages/venn/_backwards_compatibility.py:30: UserWarning: `venn2()` is retained for backwards compatibility; use `venn()` instead
#   warn((
# (<Figure size 900x900 with 1 Axes>, <AxesSubplot: >)

# %%
labels = venn.get_labels([embryo_megs, kp_megs, kpcy_megs])
venn.venn3(labels, names=['Embryo E8/E8.5', 'KP lung tumor', 'KPCY cell line'], fontsize=20)
# Out:
# (<Figure size 864x864 with 1 Axes>, <AxesSubplot:>)

# %%
labels = venn.get_labels([set([i.lower() for i in embryo_megs]), set([i.lower() for i in hek_megs])])
venn.venn2(labels, names=['Embryo E8/E8.5', 'HEK293T cell line'], fontsize=20)
# Out:
# (<Figure size 864x672 with 1 Axes>, <AxesSubplot:>)

# %%
labels = venn.get_labels([set([i.lower() for i in a549_megs]), set([i.lower() for i in kp_megs]), set([i.lower() for i in kpcy_megs])])
venn.venn3(labels, names=['A549 cell line', 'KP lung tumor', 'KPCY cell line'], fontsize=20)
# Out:
# (<Figure size 864x864 with 1 Axes>, <AxesSubplot:>)
